# %% [markdown]
# # Marketing Campaign data Analysis

# %%
#Import necessary libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
pd.set_option("display.max_columns", 100) #Make all columns seen

# %%
camp = pd.read_csv("C:/Users/Lenovo/Desktop/A4-Main/Exploratory-Data-Analysis-of-marketing-campaigns-main/Exploratory-Data-Analysis-of-marketing-campaigns-main/marketing_data.csv") #Read csv file

# %%
camp.head(20)
# Out:
#        ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0    1826        1970  Graduation       Divorced  $84,835.00         0
# 1       1        1961  Graduation         Single  $57,091.00         0
# 2   10476        1958  Graduation        Married  $67,267.00         0
# 3    1386        1967  Graduation       Together  $32,474.00         1
# 4    5371        1989  Graduation         Single  $21,474.00         1
# 5    7348        1958         PhD         Single  $71,691.00         0
# 6    4073        1954    2n Cycle        Married  $63,564.00         0
# 7    1991        1967  Graduation       Together  $44,931.00         0
# 8    4047        1954         PhD        Married  $65,324.00         0
# 9    9477        1954         PhD        Married  $65,324.00         0
# 10   2079        1947    2n Cycle        Married  $81,044.00         0
# 11   5642        1979      Master       Together  $62,499.00         1
# ...

# %%
camp.shape
# Out:
# (2240, 28)

# %%
camp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
camp.rename({" Income ":"Income"}, axis=1, inplace = True)

# %%
camp.isnull().any()
# Out:
# ID                     False
# Year_Birth             False
# Education              False
# Marital_Status         False
#  Income                 True
# Kidhome                False
# Teenhome               False
# Dt_Customer            False
# Recency                False
# MntWines               False
# MntFruits              False
# MntMeatProducts        False
# MntFishProducts        False
# MntSweetProducts       False
# MntGoldProds           False
# NumDealsPurchases      False
# NumWebPurchases        False
# NumCatalogPurchases    False
# NumStorePurchases      False
# NumWebVisitsMonth      False
# AcceptedCmp3           False
# AcceptedCmp4           False
# AcceptedCmp5           False
# AcceptedCmp1           False
# AcceptedCmp2           False
# Response               False
# Complain               False
# Country                False
# dtype: bool

# %%
camp[["Income"]].isnull().sum()
# Out:
# Income    24
# dtype: int64

# %%
camp.dropna(inplace = True)

# %%
camp[["Income"]].isnull().sum()
# Out:
# Income    0
# dtype: int64

# %%
camp["Income"] = camp["Income"].str.replace("[$,]","")

# %%
camp["Income"].head(3)
# Out:
# 0    84835.00
# 1    57091.00
# 2    67267.00
# Name: Income, dtype: object

# %%
camp["Income"] = camp["Income"].astype(dtype = float)

# %%
camp["Income"]
# Out:
# 0       84835.0
# 1       57091.0
# 2       67267.0
# 3       32474.0
# 4       21474.0
#          ...
# 2235    66476.0
# 2236    31056.0
# 2237    46310.0
# 2238    65819.0
# 2239    94871.0
# Name: Income, Length: 2216, dtype: float64

# %%
camp[["Dt_Customer"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dt_Customer  2216 non-null   object
# dtypes: object(1)
# memory usage: 34.6+ KB

# %%
camp["Dt_Customer"] = pd.to_datetime(camp["Dt_Customer"])

# %%
camp["Year_Birth"].value_counts()
# Out:
# 1976    89
# 1971    86
# 1975    83
# 1972    78
# 1978    76
# 1970    75
# 1965    74
# 1973    72
# 1969    70
# 1974    69
# 1956    55
# 1979    53
# 1977    52
# 1958    52
# 1952    52
# 1968    51
# 1966    50
# 1959    50
# 1954    49
# 1960    49
# 1955    48
# 1967    44
# 1963    44
# 1982    44
# 1962    44
# 1951    42
# 1957    41
# 1964    41
# 1983    41
# 1986    41
# 1980    39
# 1984    38
# 1981    38
# 1961    35
# 1953    35
# 1985    32
# 1949    30
# 1950    29
# 1988    29
# 1989    29
# 1987    27
# 1948    21
# 1990    18
# 1946    16
# 1947    16
# 1991    15
# 1992    13
# 1945     8
# 1944     7
# 1943     6
# 1993     5
# 1995     5
# 1994     3
# 1996     2
# 1941     1
# 1940     1
# Name: Year_Birth, dtype: int64

# %%
camp.drop(camp[camp["Year_Birth"] <= 1900].index, inplace = True)

# %%
sns.displot(camp["Year_Birth"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-7d65ca05d2e1> in <module>
# ----> 1 sns.displot(camp["Year_Birth"])
#       2 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'displot'
